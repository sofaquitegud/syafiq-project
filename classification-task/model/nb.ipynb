# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
import pickle

# %%
# Load preprocessed data
preprocessed_data_path = "C:/Users/syafi/Desktop/syafiq-project/classification-task/model/saved_data/preprocessed_data.pkl"
original_features_path = "C:/Users/syafi/Desktop/syafiq-project/classification-task/model/saved_data/original_features.pkl"

preprocessed_data = pd.read_pickle(preprocessed_data_path)
X_scaled = preprocessed_data["X_scaled"]
y_resampled = preprocessed_data["y_resampled"]
class_labels = preprocessed_data["class_labels"]

original_features = pd.read_pickle(original_features_path)

# %%
# Sample sizes for training
sample_sizes = [25, 50, 75, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000, 20000, 30000, 40000, 50000]

# %%
def stratified_subsample(X, y, train_size, random_state=42):
    if len(X) < train_size:
        raise ValueError(f"Insufficient data for sample size {train_size}.")
    X_sample, _, y_sample, _ = train_test_split(
        X, y, train_size=train_size, stratify=y, random_state=random_state
    )
    return X_sample, y_sample

# %%
results = {}
best_model = None
best_accuracy = 0
best_sample_size = 0

for sample_size in sample_sizes:
    try:
        # Create a stratified subsample
        X_sample, y_sample = stratified_subsample(
            X_scaled, y_resampled, train_size=sample_size
        )

        # Split data into train and test sets
        X_train, X_test, y_train, y_test = train_test_split(
            X_sample, y_sample, test_size=0.2, stratify=y_sample, random_state=42
        )

        # Initialize and train Naive Bayes model
        nb_model = GaussianNB()
        nb_model.fit(X_train, y_train)

        # Predict on the test set
        y_pred = nb_model.predict(X_test)

        # Evaluate the model
        report = classification_report(
            y_test, y_pred, target_names=class_labels, output_dict=True, zero_division=0
        )
        accuracy = report["accuracy"]
        print(f"Classification Report for Sample Size {sample_size}:\n")
        print(classification_report(y_test, y_pred, target_names=class_labels))

        # Save results for the current sample size
        results[sample_size] = {"accuracy": accuracy, "classification_report": report}

        # Update the best model based on accuracy
        if accuracy > best_accuracy:
            best_accuracy = accuracy
            best_model = nb_model
            best_sample_size = sample_size
            print(
                f"New best model found for sample size {sample_size} with accuracy {accuracy:.4f}"
            )

    except ValueError as e:
        print(f"Skipping sample size {sample_size}: {e}")
# Out:
# Skipping sample size 25: The test_size = 5 should be greater or equal to the number of classes = 11
# Skipping sample size 50: The test_size = 10 should be greater or equal to the number of classes = 11
# Classification Report for Sample Size 75:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.00      0.00      0.00         1
#                           Arrhythmia       0.50      1.00      0.67         1
#                      Atherosclerosis       0.50      0.50      0.50         2
#                Autonomic Dysfunction       0.00      0.00      0.00         1
#         Cardiovascular Disease (CVD)       0.00      0.00      0.00         2
#       Chronic Fatigue Syndrome (CFS)       0.67      1.00      0.80         2
#                             Diabetes       0.33      1.00      0.50         1
#                              Healthy       0.50      1.00      0.67         1
#                         Hypertension       0.00      0.00      0.00         2
# Respiratory Disease (COPD or Asthma)       1.00      1.00      1.00         1
#             Stress-related Disorders       0.00      0.00      0.00         1
#
#                             accuracy                           0.47        15
#                            macro avg       0.32      0.50      0.38        15
#                         weighted avg       0.31      0.47      0.36        15
#
# New best model found for sample size 75 with accuracy 0.4667
# c:\Users\syafi\anaconda3\envs\mydatascienv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\syafi\anaconda3\envs\mydatascienv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\syafi\anaconda3\envs\mydatascienv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Report for Sample Size 100:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      0.50      0.67         2
#                           Arrhythmia       0.33      1.00      0.50         1
#                      Atherosclerosis       1.00      0.50      0.67         2
#                Autonomic Dysfunction       1.00      1.00      1.00         2
#         Cardiovascular Disease (CVD)       1.00      0.50      0.67         2
#       Chronic Fatigue Syndrome (CFS)       0.40      1.00      0.57         2
#                             Diabetes       0.00      0.00      0.00         2
#                              Healthy       0.67      1.00      0.80         2
#                         Hypertension       0.00      0.00      0.00         2
# Respiratory Disease (COPD or Asthma)       0.50      1.00      0.67         1
#             Stress-related Disorders       0.00      0.00      0.00         2
#
#                             accuracy                           0.55        20
#                            macro avg       0.54      0.59      0.50        20
#                         weighted avg       0.55      0.55      0.50        20
#
# New best model found for sample size 100 with accuracy 0.5500
# c:\Users\syafi\anaconda3\envs\mydatascienv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\syafi\anaconda3\envs\mydatascienv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\syafi\anaconda3\envs\mydatascienv\lib\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Classification Report for Sample Size 250:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      0.60      0.75         5
#                           Arrhythmia       0.44      1.00      0.62         4
#                      Atherosclerosis       1.00      1.00      1.00         5
#                Autonomic Dysfunction       1.00      1.00      1.00         4
#         Cardiovascular Disease (CVD)       1.00      0.50      0.67         4
#       Chronic Fatigue Syndrome (CFS)       0.62      1.00      0.77         5
#                             Diabetes       1.00      1.00      1.00         4
#                              Healthy       0.67      1.00      0.80         4
#                         Hypertension       1.00      0.20      0.33         5
# Respiratory Disease (COPD or Asthma)       0.71      1.00      0.83         5
#             Stress-related Disorders       1.00      0.20      0.33         5
#
#                             accuracy                           0.76        50
#                            macro avg       0.86      0.77      0.74        50
#                         weighted avg       0.86      0.76      0.73        50
#
# New best model found for sample size 250 with accuracy 0.7600
# Classification Report for Sample Size 500:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       1.00      0.33      0.50         9
#                           Arrhythmia       0.57      0.89      0.70         9
#                      Atherosclerosis       0.78      0.78      0.78         9
#                Autonomic Dysfunction       1.00      1.00      1.00         9
#         Cardiovascular Disease (CVD)       1.00      0.33      0.50         9
#       Chronic Fatigue Syndrome (CFS)       0.53      1.00      0.69         9
#                             Diabetes       1.00      1.00      1.00         9
#                              Healthy       0.69      1.00      0.82         9
#                         Hypertension       0.29      0.22      0.25         9
# Respiratory Disease (COPD or Asthma)       0.90      0.90      0.90        10
#             Stress-related Disorders       0.67      0.44      0.53         9
#
#                             accuracy                           0.72       100
#                            macro avg       0.77      0.72      0.70       100
#                         weighted avg       0.77      0.72      0.70       100
#
# Classification Report for Sample Size 750:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.50      0.36      0.42        14
#                           Arrhythmia       0.67      0.62      0.64        13
#                      Atherosclerosis       0.80      0.92      0.86        13
#                Autonomic Dysfunction       1.00      1.00      1.00        14
#         Cardiovascular Disease (CVD)       1.00      0.36      0.53        14
#       Chronic Fatigue Syndrome (CFS)       0.45      0.71      0.56        14
#                             Diabetes       0.88      1.00      0.93        14
#                              Healthy       0.68      1.00      0.81        13
#                         Hypertension       0.67      0.43      0.52        14
# Respiratory Disease (COPD or Asthma)       0.81      1.00      0.90        13
#             Stress-related Disorders       0.42      0.36      0.38        14
#
#                             accuracy                           0.70       150
#                            macro avg       0.72      0.70      0.69       150
#                         weighted avg       0.72      0.70      0.68       150
#
# Classification Report for Sample Size 1000:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.67      0.44      0.53        18
#                           Arrhythmia       0.76      0.89      0.82        18
#                      Atherosclerosis       0.82      1.00      0.90        18
#                Autonomic Dysfunction       1.00      1.00      1.00        19
#         Cardiovascular Disease (CVD)       1.00      0.44      0.62        18
#       Chronic Fatigue Syndrome (CFS)       0.55      0.94      0.69        18
#                             Diabetes       1.00      0.94      0.97        18
#                              Healthy       0.64      0.95      0.77        19
#                         Hypertension       0.80      0.44      0.57        18
# Respiratory Disease (COPD or Asthma)       0.90      1.00      0.95        18
#             Stress-related Disorders       0.58      0.39      0.47        18
#
#                             accuracy                           0.77       200
#                            macro avg       0.79      0.77      0.75       200
#                         weighted avg       0.79      0.77      0.75       200
#
# New best model found for sample size 1000 with accuracy 0.7700
# Classification Report for Sample Size 2500:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.62      0.35      0.44        46
#                           Arrhythmia       0.79      0.84      0.82        45
#                      Atherosclerosis       0.83      0.87      0.85        45
#                Autonomic Dysfunction       0.96      1.00      0.98        45
#         Cardiovascular Disease (CVD)       0.87      0.43      0.58        46
#       Chronic Fatigue Syndrome (CFS)       0.51      0.93      0.66        46
#                             Diabetes       0.98      0.91      0.94        45
#                              Healthy       0.60      0.96      0.74        45
#                         Hypertension       0.85      0.50      0.63        46
# Respiratory Disease (COPD or Asthma)       0.86      0.96      0.91        46
#             Stress-related Disorders       0.70      0.51      0.59        45
#
#                             accuracy                           0.75       500
#                            macro avg       0.78      0.75      0.74       500
#                         weighted avg       0.78      0.75      0.74       500
#
# Classification Report for Sample Size 5000:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.54      0.32      0.40        91
#                           Arrhythmia       0.74      0.87      0.80        91
#                      Atherosclerosis       0.79      0.89      0.84        91
#                Autonomic Dysfunction       0.98      1.00      0.99        91
#         Cardiovascular Disease (CVD)       0.91      0.47      0.62        90
#       Chronic Fatigue Syndrome (CFS)       0.56      0.98      0.71        91
#                             Diabetes       0.94      0.91      0.93        91
#                              Healthy       0.65      1.00      0.79        91
#                         Hypertension       0.85      0.43      0.57        91
# Respiratory Disease (COPD or Asthma)       0.91      0.89      0.90        91
#             Stress-related Disorders       0.59      0.49      0.54        91
#
#                             accuracy                           0.75      1000
#                            macro avg       0.77      0.75      0.73      1000
#                         weighted avg       0.77      0.75      0.73      1000
#
# Classification Report for Sample Size 7500:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.56      0.33      0.41       136
#                           Arrhythmia       0.70      0.85      0.77       136
#                      Atherosclerosis       0.84      0.90      0.87       137
#                Autonomic Dysfunction       0.97      1.00      0.99       136
#         Cardiovascular Disease (CVD)       0.94      0.47      0.62       137
#       Chronic Fatigue Syndrome (CFS)       0.53      0.98      0.69       137
#                             Diabetes       0.96      0.88      0.92       136
#                              Healthy       0.65      0.98      0.78       136
#                         Hypertension       0.77      0.37      0.50       137
# Respiratory Disease (COPD or Asthma)       0.86      0.93      0.89       136
#             Stress-related Disorders       0.69      0.51      0.59       136
#
#                             accuracy                           0.75      1500
#                            macro avg       0.77      0.75      0.73      1500
#                         weighted avg       0.77      0.75      0.73      1500
#
# Classification Report for Sample Size 10000:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.60      0.36      0.45       182
#                           Arrhythmia       0.78      0.86      0.82       181
#                      Atherosclerosis       0.82      0.92      0.87       182
#                Autonomic Dysfunction       0.98      1.00      0.99       182
#         Cardiovascular Disease (CVD)       0.96      0.43      0.60       182
#       Chronic Fatigue Syndrome (CFS)       0.51      0.96      0.67       182
#                             Diabetes       0.92      0.92      0.92       182
#                              Healthy       0.66      0.99      0.79       182
#                         Hypertension       0.73      0.34      0.46       182
# Respiratory Disease (COPD or Asthma)       0.83      0.91      0.87       181
#             Stress-related Disorders       0.67      0.50      0.57       182
#
#                             accuracy                           0.75      2000
#                            macro avg       0.77      0.75      0.73      2000
#                         weighted avg       0.77      0.75      0.73      2000
#
# Classification Report for Sample Size 20000:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.59      0.35      0.44       364
#                           Arrhythmia       0.74      0.85      0.79       363
#                      Atherosclerosis       0.79      0.93      0.85       363
#                Autonomic Dysfunction       0.98      1.00      0.99       364
#         Cardiovascular Disease (CVD)       0.93      0.40      0.56       364
#       Chronic Fatigue Syndrome (CFS)       0.53      0.97      0.68       364
#                             Diabetes       0.94      0.89      0.92       364
#                              Healthy       0.67      0.99      0.80       363
#                         Hypertension       0.71      0.38      0.50       364
# Respiratory Disease (COPD or Asthma)       0.86      0.94      0.90       363
#             Stress-related Disorders       0.66      0.49      0.56       364
#
#                             accuracy                           0.74      4000
#                            macro avg       0.76      0.74      0.73      4000
#                         weighted avg       0.76      0.74      0.73      4000
#
# Classification Report for Sample Size 30000:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.58      0.36      0.44       546
#                           Arrhythmia       0.74      0.85      0.79       545
#                      Atherosclerosis       0.81      0.88      0.84       545
#                Autonomic Dysfunction       0.97      1.00      0.98       545
#         Cardiovascular Disease (CVD)       0.92      0.45      0.60       546
#       Chronic Fatigue Syndrome (CFS)       0.53      0.96      0.68       546
#                             Diabetes       0.94      0.90      0.92       545
#                              Healthy       0.65      0.99      0.79       545
#                         Hypertension       0.70      0.35      0.47       546
# Respiratory Disease (COPD or Asthma)       0.84      0.94      0.89       546
#             Stress-related Disorders       0.65      0.46      0.54       545
#
#                             accuracy                           0.74      6000
#                            macro avg       0.76      0.74      0.72      6000
#                         weighted avg       0.76      0.74      0.72      6000
#
# Classification Report for Sample Size 40000:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.59      0.36      0.45       728
#                           Arrhythmia       0.77      0.84      0.80       727
#                      Atherosclerosis       0.80      0.89      0.84       727
#                Autonomic Dysfunction       0.97      1.00      0.99       727
#         Cardiovascular Disease (CVD)       0.91      0.45      0.60       727
#       Chronic Fatigue Syndrome (CFS)       0.53      0.96      0.68       727
#                             Diabetes       0.93      0.91      0.92       727
#                              Healthy       0.64      0.99      0.77       727
#                         Hypertension       0.74      0.38      0.50       727
# Respiratory Disease (COPD or Asthma)       0.87      0.94      0.90       728
#             Stress-related Disorders       0.65      0.45      0.54       728
#
#                             accuracy                           0.74      8000
#                            macro avg       0.76      0.74      0.73      8000
#                         weighted avg       0.76      0.74      0.73      8000
#
# Classification Report for Sample Size 50000:
#
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.64      0.38      0.47       909
#                           Arrhythmia       0.75      0.83      0.79       909
#                      Atherosclerosis       0.80      0.90      0.85       909
#                Autonomic Dysfunction       0.97      1.00      0.99       909
#         Cardiovascular Disease (CVD)       0.91      0.43      0.58       909
#       Chronic Fatigue Syndrome (CFS)       0.53      0.96      0.68       909
#                             Diabetes       0.94      0.90      0.92       909
#                              Healthy       0.65      0.99      0.79       909
#                         Hypertension       0.72      0.37      0.49       909
# Respiratory Disease (COPD or Asthma)       0.83      0.95      0.89       910
#             Stress-related Disorders       0.60      0.45      0.51       909
#
#                             accuracy                           0.74     10000
#                            macro avg       0.76      0.74      0.72     10000
#                         weighted avg       0.76      0.74      0.72     10000

# %%
# Save the model
with open("nb_model", "wb") as model_file:
    pickle.dump(best_model, model_file)
    print(f"\nModel saved as {model_file} with accuracy {best_accuracy:.4f}")
