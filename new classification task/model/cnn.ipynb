# %%
import pandas as pd
import numpy as np 
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Conv1D, Flatten, Dropout, MaxPooling1D, Input
from keras.utils import to_categorical
from sklearn.metrics import classification_report, accuracy_score
import pickle

# %%
# Load preprocessed data
with open(
    "C:/Users/syafi/Desktop/py-1/ignore file/preprocessed_data.pkl",
    "rb",
) as f:
    X_train, X_test, y_train, y_test = pickle.load(f)

with open(
    "C:/Users/syafi/Desktop/py-1/ignore file/label_mapping.pkl", "rb",
) as f:
    label_mapping = pickle.load(f)
class_labels = list(label_mapping.keys())

# Display train and test sizes
print(f"Train size: {len(X_train)}")
print(f"Test size: {len(X_test)}")
# Out:
# Train size: 1344719
# Test size: 336180

# %%
# Number of classes
num_classes = len(class_labels)

# %%
# Convert labels to categorical
y_train_cat = to_categorical(y_train, num_classes=num_classes)
y_test_cat = to_categorical(y_test, num_classes=num_classes)

# %%
# Define test set function
def expand_test_set(X_test, y_test, repeat_factor):
    """
    Expand the test set by repeating each sample multiple times
    """
    X_test_expanded = np.repeat(X_test, repeats=repeat_factor, axis=0)
    y_test_expanded = np.repeat(y_test, repeats=repeat_factor)
    return X_test_expanded, y_test_expanded

# %%
# Evaluate the CNN Model
def evaluate_cnn_model(model, X_test_subset, y_test_subset, class_labels):
    """
    Evaluate the CNN Model and return classification metrics with dynamic class labels
    """

    # Predictions
    predictions = model.predict(X_test_subset)
    predictions = np.argmax(predictions, axis=1)

    # Calculate accuracy
    accuracy = accuracy_score(y_test_subset, predictions)

    # Dynamically identify the classes present in the test set
    unique_classes = np.unique(y_test_subset)

    # Ensure labels and target names are consistent
    labels = list(unique_classes) # Labels to include in the report
    dynamic_labels = [class_labels[label] for label in labels] # Map labels to name

    # Generate classification report with consistent labels and target names
    report = classification_report(
        y_test_subset, predictions, labels=labels, target_names=dynamic_labels, zero_division=0, output_dict=True
    )

    return accuracy, report, predictions, dynamic_labels

# %%
# Build CNN Model
def build_cnn(input_shape, num_classes):
    """
    Build a CNN model with Input Layer
    
    Args:
        input shape (tuple): Shape of the input data
        num_classes (int): Number of output classes
    Returns:
        Compiled CNN model
    """
    model = Sequential(
        [
            Input(shape=input_shape),
            Conv1D(filters=32, kernel_size=3, activation="relu"),
            MaxPooling1D(pool_size=2),
            Dropout(0.25),
            Conv1D(filters=64, kernel_size=3, activation="relu"),
            MaxPooling1D(pool_size=2),
            Dropout(0.25),
            Flatten(),
            Dense(128, activation="relu"),
            Dropout(0.5),
            Dense(num_classes, activation="softmax"),
        ]
    )
    model.compile(
        optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
# Define sizes for experiments
sample_sizes = [25, 50, 75, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000, 20000, 30000, 40000, 50000]
training_sizes = [20, 40, 60, 80, 200, 400, 600, 800, 2000, 4000, 6000, 8000, 16000, 24000, 32000, 40000]
testing_sizes = [5, 10, 15, 20, 50, 100, 150, 200, 500, 1000, 1500, 2000, 4000, 6000, 8000, 10000]

# Container for results
cnn_results = []
best_accuracy = 0
best_model = None
best_sample_size = 0

# %%
# Iterate through sample, training, and testing sizes
for sample_size, train_size, test_size in zip(
    sample_sizes, training_sizes, testing_sizes
):
    # Select subset of training and testing data
    X_train_subset, y_train_subset = X_train[:train_size], y_train_cat[:train_size]
    X_test_subset, y_test_subset = X_test[:test_size], y_test[:test_size]

    # Expand the test set for alignment
    repeat_factor = 11
    X_test_expanded, y_test_expanded = expand_test_set(
        X_test_subset, y_test_subset, repeat_factor
    )
    y_test_expanded_cat = to_categorical(y_test_expanded, num_classes=num_classes)

    # Build the CNN model
    input_shape = (X_train_subset.shape[1], 1)  # Assuming 1D input data
    cnn_model = build_cnn(input_shape=input_shape, num_classes=num_classes)

    # Reshape data for CNN input
    X_train_subset = X_train_subset.reshape(-1, X_train_subset.shape[1], 1)
    X_test_expanded = X_test_expanded.reshape(-1, X_test_expanded.shape[1], 1)

    # Train the CNN model
    cnn_model.fit(X_train_subset, y_train_subset, epochs=10, batch_size=32, verbose=0)

    # Evaluate the CNN model
    accuracy, report, predictions, dynamic_labels = evaluate_cnn_model(
        cnn_model, X_test_expanded, y_test_expanded, class_labels
    )

    # Print results for the current iteration
    print(f"\nCNN Sample size {sample_size} - Accuracy: {accuracy:.4f}")
    print(
        classification_report(
            y_test_expanded,
            predictions,
            labels=np.unique(y_test_expanded),
            target_names=dynamic_labels,
            zero_division=0,
        )
    )

    # Store results
    report_flattened = {
        **{
            f"{label}_{metric}": value
            for label, metrics in report.items()
            if isinstance(metrics, dict)
            for metric, value in metrics.items()
        },
        "sample_size": sample_size,
        "train_size": train_size,
        "test_size": test_size,
        "accuracy": accuracy,
    }
    cnn_results.append(report_flattened)

    # Update the best model
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_model = cnn_model
        best_sample_size = sample_size
        print(
            f"New best model found for sample size {sample_size} with accuracy {accuracy:.4f}"
        )
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#
# CNN Sample size 25 - Accuracy: 0.2000
#                                       precision    recall  f1-score   support
#
#                Autonomic Dysfunction       0.33      1.00      0.50        11
#       Chronic Fatigue Syndrome (CFS)       0.00      0.00      0.00        11
#                              Healthy       0.00      0.00      0.00        11
#                         Hypertension       0.00      0.00      0.00        11
# Respiratory Disease (COPD or Asthma)       0.00      0.00      0.00        11
#
#                            micro avg       0.25      0.20      0.22        55
#                            macro avg       0.07      0.20      0.10        55
#                         weighted avg       0.07      0.20      0.10        55
#
# New best model found for sample size 25 with accuracy 0.2000
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#
# CNN Sample size 50 - Accuracy: 0.0000
#                                       precision    recall  f1-score   support
#
#                          Arrhythmias       0.00      0.00      0.00      11.0
#                Autonomic Dysfunction       0.00      0.00      0.00      11.0
#       Chronic Fatigue Syndrome (CFS)       0.00      0.00      0.00      11.0
#                             Diabetes       0.00      0.00      0.00      11.0
#                              Healthy       0.00      0.00      0.00      22.0
#                         Hypertension       0.00      0.00      0.00      11.0
# Respiratory Disease (COPD or Asthma)       0.00      0.00      0.00      22.0
#             Stress-related Disorders       0.00      0.00      0.00      11.0
#
#                            micro avg       0.00      0.00      0.00     110.0
#                            macro avg       0.00      0.00      0.00     110.0
#                         weighted avg       0.00      0.00      0.00     110.0
#
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000206B345FAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000206B345FAF0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
#
# CNN Sample size 75 - Accuracy: 0.1333
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.00      0.00      0.00        11
#                          Arrhythmias       0.00      0.00      0.00        11
#                Autonomic Dysfunction       0.00      0.00      0.00        22
#       Chronic Fatigue Syndrome (CFS)       0.00      0.00      0.00        11
#                             Diabetes       0.00      0.00      0.00        11
#                              Healthy       0.00      0.00      0.00        33
#                         Hypertension       0.00      0.00      0.00        11
# Respiratory Disease (COPD or Asthma)       0.00      0.00      0.00        33
#             Stress-related Disorders       0.29      1.00      0.44        22
#
#                            micro avg       0.17      0.13      0.15       165
#                            macro avg       0.03      0.11      0.05       165
#                         weighted avg       0.04      0.13      0.06       165
#
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
#
# CNN Sample size 100 - Accuracy: 0.0500
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.00      0.00      0.00        33
#                          Arrhythmias       0.00      0.00      0.00        11
#                Autonomic Dysfunction       0.00      0.00      0.00        22
#       Chronic Fatigue Syndrome (CFS)       0.00      0.00      0.00        22
#                             Diabetes       0.00      0.00      0.00        22
#                              Healthy       0.00      0.00      0.00        33
#                         Hypertension       0.00      0.00      0.00        11
# Respiratory Disease (COPD or Asthma)       0.00      0.00      0.00        44
#             Stress-related Disorders       0.20      0.50      0.29        22
#
#                            micro avg       0.08      0.05      0.06       220
#                            macro avg       0.02      0.06      0.03       220
#                         weighted avg       0.02      0.05      0.03       220
#
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# CNN Sample size 250 - Accuracy: 0.3000
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.00      0.00      0.00        33
#                          Arrhythmias       0.33      0.33      0.33        33
#                Autonomic Dysfunction       0.00      0.00      0.00        88
#         Cardiovascular Disease (CVD)       0.33      0.25      0.29        44
#       Chronic Fatigue Syndrome (CFS)       0.27      1.00      0.43        66
#                             Diabetes       0.00      0.00      0.00        55
#                              Healthy       0.00      0.00      0.00        55
#                         Hypertension       0.75      0.50      0.60        66
# Respiratory Disease (COPD or Asthma)       0.00      0.00      0.00        44
#             Stress-related Disorders       0.31      0.67      0.42        66
#
#                            micro avg       0.33      0.30      0.31       550
#                            macro avg       0.20      0.27      0.21       550
#                         weighted avg       0.21      0.30      0.22       550
#
# New best model found for sample size 250 with accuracy 0.3000
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# CNN Sample size 500 - Accuracy: 0.3900
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.00      0.00      0.00       110
#                          Arrhythmias       0.40      0.33      0.36        66
#                      Atherosclerosis       0.00      0.00      0.00        33
#                Autonomic Dysfunction       0.41      0.69      0.51       143
#         Cardiovascular Disease (CVD)       0.18      0.29      0.22        77
#       Chronic Fatigue Syndrome (CFS)       0.59      0.91      0.71       121
#                             Diabetes       1.00      0.12      0.22        88
#                              Healthy       0.29      1.00      0.44        66
#                         Hypertension       0.50      0.21      0.30       154
# Respiratory Disease (COPD or Asthma)       0.50      0.09      0.15       121
#             Stress-related Disorders       0.42      0.45      0.43       121
#
#                             accuracy                           0.39      1100
#                            macro avg       0.39      0.37      0.31      1100
#                         weighted avg       0.42      0.39      0.33      1100
#
# New best model found for sample size 500 with accuracy 0.3900
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# CNN Sample size 750 - Accuracy: 0.4867
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.00      0.00      0.00       187
#                          Arrhythmias       0.50      0.22      0.31        99
#                      Atherosclerosis       0.44      0.64      0.52       121
#                Autonomic Dysfunction       0.51      1.00      0.68       209
#         Cardiovascular Disease (CVD)       0.45      0.42      0.43       132
#       Chronic Fatigue Syndrome (CFS)       0.65      0.92      0.76       132
#                             Diabetes       1.00      0.10      0.18       110
#                              Healthy       0.33      0.90      0.49       110
#                         Hypertension       0.64      0.39      0.48       198
# Respiratory Disease (COPD or Asthma)       0.56      0.28      0.37       198
#             Stress-related Disorders       0.41      0.50      0.45       154
#
#                             accuracy                           0.49      1650
#                            macro avg       0.50      0.49      0.42      1650
#                         weighted avg       0.49      0.49      0.43      1650
#
# New best model found for sample size 750 with accuracy 0.4867
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# CNN Sample size 1000 - Accuracy: 0.4950
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.00      0.00      0.00       231
#                          Arrhythmias       0.60      0.43      0.50       154
#                      Atherosclerosis       0.33      0.87      0.47       165
#                Autonomic Dysfunction       0.59      0.92      0.72       264
#         Cardiovascular Disease (CVD)       0.40      0.12      0.18       187
#       Chronic Fatigue Syndrome (CFS)       0.82      0.90      0.86       220
#                             Diabetes       0.25      0.08      0.12       132
#                              Healthy       0.36      0.93      0.52       154
#                         Hypertension       0.78      0.26      0.39       297
# Respiratory Disease (COPD or Asthma)       0.46      0.33      0.39       198
#             Stress-related Disorders       0.46      0.61      0.52       198
#
#                             accuracy                           0.49      2200
#                            macro avg       0.46      0.50      0.43      2200
#                         weighted avg       0.48      0.49      0.44      2200
#
# New best model found for sample size 1000 with accuracy 0.4950
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# CNN Sample size 2500 - Accuracy: 0.7320
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.72      0.87      0.79       517
#                          Arrhythmias       0.67      0.69      0.68       462
#                      Atherosclerosis       0.61      0.76      0.68       605
#                Autonomic Dysfunction       0.81      0.98      0.89       495
#         Cardiovascular Disease (CVD)       0.72      0.70      0.71       517
#       Chronic Fatigue Syndrome (CFS)       0.87      0.94      0.90       539
#                             Diabetes       0.75      0.50      0.60       396
#                              Healthy       0.71      0.61      0.66       484
#                         Hypertension       0.90      0.49      0.63       583
# Respiratory Disease (COPD or Asthma)       0.67      0.67      0.67       462
#             Stress-related Disorders       0.71      0.80      0.75       440
#
#                             accuracy                           0.73      5500
#                            macro avg       0.74      0.73      0.72      5500
#                         weighted avg       0.74      0.73      0.73      5500
#
# New best model found for sample size 2500 with accuracy 0.7320
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
#
# CNN Sample size 5000 - Accuracy: 0.7780
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.80      0.55      0.65       968
#                          Arrhythmias       0.72      0.77      0.74       891
#                      Atherosclerosis       0.64      0.87      0.74      1089
#                Autonomic Dysfunction       0.91      0.98      0.94      1034
#         Cardiovascular Disease (CVD)       0.88      0.71      0.78      1122
#       Chronic Fatigue Syndrome (CFS)       0.97      0.95      0.96      1089
#                             Diabetes       0.66      0.81      0.72       792
#                              Healthy       0.62      0.87      0.73      1012
#                         Hypertension       0.79      0.66      0.72      1133
# Respiratory Disease (COPD or Asthma)       0.83      0.66      0.73       869
#             Stress-related Disorders       0.89      0.73      0.80      1001
#
#                             accuracy                           0.78     11000
#                            macro avg       0.79      0.78      0.77     11000
#                         weighted avg       0.80      0.78      0.78     11000
#
# New best model found for sample size 5000 with accuracy 0.7780
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# CNN Sample size 7500 - Accuracy: 0.8200
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.74      0.89      0.81      1463
#                          Arrhythmias       0.86      0.73      0.79      1375
#                      Atherosclerosis       0.71      0.79      0.75      1507
#                Autonomic Dysfunction       0.88      1.00      0.94      1507
#         Cardiovascular Disease (CVD)       0.86      0.71      0.78      1573
#       Chronic Fatigue Syndrome (CFS)       0.97      0.95      0.96      1650
#                             Diabetes       0.66      0.77      0.71      1254
#                              Healthy       0.81      0.74      0.77      1628
#                         Hypertension       0.85      0.82      0.83      1639
# Respiratory Disease (COPD or Asthma)       0.85      0.82      0.84      1408
#             Stress-related Disorders       0.86      0.79      0.82      1496
#
#                             accuracy                           0.82     16500
#                            macro avg       0.82      0.82      0.82     16500
#                         weighted avg       0.83      0.82      0.82     16500
#
# New best model found for sample size 7500 with accuracy 0.8200
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#
# CNN Sample size 10000 - Accuracy: 0.8370
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.67      0.90      0.77      1914
#                          Arrhythmias       0.81      0.83      0.82      1980
#                      Atherosclerosis       0.79      0.81      0.80      1936
#                Autonomic Dysfunction       0.87      0.99      0.93      2057
#         Cardiovascular Disease (CVD)       0.83      0.80      0.82      2068
#       Chronic Fatigue Syndrome (CFS)       0.98      0.95      0.97      2211
#                             Diabetes       0.81      0.77      0.79      1606
#                              Healthy       0.81      0.64      0.72      2101
#                         Hypertension       0.92      0.80      0.86      2145
# Respiratory Disease (COPD or Asthma)       0.84      0.91      0.87      1892
#             Stress-related Disorders       0.89      0.80      0.84      2090
#
#                             accuracy                           0.84     22000
#                            macro avg       0.84      0.84      0.83     22000
#                         weighted avg       0.84      0.84      0.84     22000
#
# New best model found for sample size 10000 with accuracy 0.8370
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
#
# CNN Sample size 20000 - Accuracy: 0.8865
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.81      0.92      0.86      3762
#                          Arrhythmias       0.89      0.91      0.90      4059
#                      Atherosclerosis       0.81      0.88      0.84      3883
#                Autonomic Dysfunction       0.91      1.00      0.95      3806
#         Cardiovascular Disease (CVD)       0.90      0.80      0.85      4290
#       Chronic Fatigue Syndrome (CFS)       0.99      0.94      0.96      4169
#                             Diabetes       0.86      0.91      0.89      3641
#                              Healthy       0.91      0.83      0.87      4345
#                         Hypertension       0.90      0.86      0.88      4268
# Respiratory Disease (COPD or Asthma)       0.88      0.89      0.88      3773
#             Stress-related Disorders       0.89      0.83      0.86      4004
#
#                             accuracy                           0.89     44000
#                            macro avg       0.89      0.89      0.89     44000
#                         weighted avg       0.89      0.89      0.89     44000
#
# New best model found for sample size 20000 with accuracy 0.8865
# 2063/2063 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step
#
# CNN Sample size 30000 - Accuracy: 0.9152
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.87      0.94      0.90      5731
#                          Arrhythmias       0.93      0.94      0.94      6226
#                      Atherosclerosis       0.92      0.81      0.86      5753
#                Autonomic Dysfunction       0.97      1.00      0.98      5962
#         Cardiovascular Disease (CVD)       0.89      0.89      0.89      6204
#       Chronic Fatigue Syndrome (CFS)       0.99      0.96      0.97      6039
#                             Diabetes       0.89      0.97      0.93      5698
#                              Healthy       0.91      0.90      0.90      6358
#                         Hypertension       0.89      0.89      0.89      6171
# Respiratory Disease (COPD or Asthma)       0.88      0.90      0.89      5797
#             Stress-related Disorders       0.94      0.86      0.90      6061
#
#                             accuracy                           0.92     66000
#                            macro avg       0.92      0.92      0.91     66000
#                         weighted avg       0.92      0.92      0.91     66000
#
# New best model found for sample size 30000 with accuracy 0.9152
# 2750/2750 ━━━━━━━━━━━━━━━━━━━━ 3s 1ms/step
#
# CNN Sample size 40000 - Accuracy: 0.9146
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.86      0.96      0.91      8019
#                          Arrhythmias       0.93      0.94      0.93      8217
#                      Atherosclerosis       0.94      0.78      0.85      7986
#                Autonomic Dysfunction       0.95      1.00      0.98      8052
#         Cardiovascular Disease (CVD)       0.89      0.87      0.88      8283
#       Chronic Fatigue Syndrome (CFS)       0.98      0.95      0.97      8052
#                             Diabetes       0.93      0.96      0.94      7711
#                              Healthy       0.95      0.86      0.90      8162
#                         Hypertension       0.86      0.92      0.89      8063
# Respiratory Disease (COPD or Asthma)       0.85      0.92      0.89      7568
#             Stress-related Disorders       0.93      0.90      0.92      7887
#
#                             accuracy                           0.91     88000
#                            macro avg       0.92      0.91      0.91     88000
#                         weighted avg       0.92      0.91      0.91     88000
#
# 3438/3438 ━━━━━━━━━━━━━━━━━━━━ 4s 1ms/step
#
# CNN Sample size 50000 - Accuracy: 0.9283
#                                       precision    recall  f1-score   support
#
#                              Anaemia       0.90      0.97      0.93      9856
#                          Arrhythmias       0.95      0.94      0.94     10296
#                      Atherosclerosis       0.89      0.90      0.89     10109
#                Autonomic Dysfunction       0.95      1.00      0.98     10329
#         Cardiovascular Disease (CVD)       0.93      0.85      0.88     10153
#       Chronic Fatigue Syndrome (CFS)       0.99      0.96      0.97      9966
#                             Diabetes       0.93      0.98      0.96      9625
#                              Healthy       0.95      0.91      0.93     10197
#                         Hypertension       0.91      0.88      0.90      9889
# Respiratory Disease (COPD or Asthma)       0.88      0.91      0.89      9537
#             Stress-related Disorders       0.93      0.92      0.93     10043
#
#                             accuracy                           0.93    110000
#                            macro avg       0.93      0.93      0.93    110000
#                         weighted avg       0.93      0.93      0.93    110000
#
# New best model found for sample size 50000 with accuracy 0.9283

# %%
# Save the best model
if best_model is not None:
    best_model_file = f"best_cnn_model_sample_size_{best_sample_size}.h5"
    best_model.save(best_model_file)
    print(
        f"\nBest CNN model saved as {best_model_file} with accuracy {best_accuracy:.4f}"
    )

# %%
# Save results to a CSV file for further analysis
cnn_results_df = pd.DataFrame(cnn_results)
cnn_results_df.to_csv("cnn_results.csv", index=False)
print("\nResults saved to 'cnn_results.csv'")
