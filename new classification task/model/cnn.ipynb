# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv1D, Flatten, Dropout, MaxPooling1D, Input
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import classification_report, accuracy_score
import pickle

# %%
# Load preprocessed data
with open(
    r"C:\Users\syafi\Desktop\TM\Heart_Rate_Classification\new classification task\saved_data\preprocessed_data.pkl",
    "rb",
) as f:
    X_train, X_test, y_train, y_test = pickle.load(f)

# Display train and test sizes
print(f"Train size: {len(X_train)}")
print(f"Test size: {len(X_test)}")
# Out:
# Train size: 1177208
# Test size: 294302

# %%
# Class labels for reporting
class_labels = [
    "Atherosclerosis",
    "Hypertension",
    "Cardiovascular Disease (CVD)",
    "Chronic Fatigue Syndrome (CFS)",
    "Respiratory Disease (COPD or Asthma)",
    "Stress-related Disorders",
    "Arrhythmias",
    "Healthy",
    "Autonomic Dysfunction",
    "Diabetes",
    "Anaemia",
]

# Number of classes
num_classes = len(class_labels)

# Convert labels to categorical
y_train_cat = to_categorical(y_train, num_classes=num_classes)
y_test_cat = to_categorical(y_test, num_classes=num_classes)

# %%
def expand_test_set(X_test, y_test, repeat_factor):
    """
    Expand the test set by repeating each sample multiple times.
    """
    X_test_expanded = np.repeat(X_test, repeats=repeat_factor, axis=0)
    y_test_expanded = np.repeat(y_test, repeats=repeat_factor)
    return X_test_expanded, y_test_expanded

# %%
def evaluate_cnn_model(model, X_test_subset, y_test_subset, class_labels):
    """
    Evaluate the CNN model and return classification metrics with dynamic class labels.
    """
    # Predictions
    predictions = model.predict(X_test_subset)
    predictions = np.argmax(predictions, axis=1)

    # Calculate accuracy
    accuracy = accuracy_score(y_test_subset, predictions)

    # Dynamically identify the classes present in the test set
    unique_classes = np.unique(y_test_subset)

    # Ensure labels and target_names are consistent
    labels = list(unique_classes)  # Labels to include in the report
    dynamic_labels = [class_labels[label] for label in labels]  # Map labels to names

    # Generate classification report with consistent labels and target names
    report = classification_report(
        y_test_subset,
        predictions,
        labels=labels,
        target_names=dynamic_labels,
        zero_division=0,
        output_dict=True,
    )

    return accuracy, report, predictions, dynamic_labels

# %%
def build_cnn(input_shape, num_classes):
    """
    Build a CNN model with Input layer.

    Args:
        input_shape (tuple): Shape of the input data.
        num_classes (int): Number of output classes.

    Returns:
        Compiled CNN model.
    """
    model = Sequential(
        [
            Input(shape=input_shape),
            Conv1D(filters=32, kernel_size=3, activation="relu"),
            MaxPooling1D(pool_size=2),
            Dropout(0.25),
            Conv1D(filters=64, kernel_size=3, activation="relu"),
            MaxPooling1D(pool_size=2),
            Dropout(0.25),
            Flatten(),
            Dense(128, activation="relu"),
            Dropout(0.5),
            Dense(num_classes, activation="softmax"),
        ]
    )

    model.compile(
        optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"]
    )
    return model

# %%
# Define sizes for experiments
sample_sizes = [25, 50, 75, 100, 250, 500, 750, 1000, 2500, 5000, 7500, 10000, 20000, 30000, 40000, 50000]
training_sizes = [20, 40, 60, 80, 200, 400, 600, 800, 2000, 4000, 6000, 8000, 16000, 24000, 32000, 40000]
testing_sizes = [5, 10, 15, 20, 50, 100, 150, 200, 500, 1000, 1500, 2000, 4000, 6000, 8000, 10000]

# %%
# Container for results
cnn_results = []
best_accuracy = 0
best_model = None
best_sample_size = 0

# Iterate through sample, training, and testing sizes
for sample_size, train_size, test_size in zip(
    sample_sizes, training_sizes, testing_sizes
):
    # Select subset of training and testing data
    X_train_subset, y_train_subset = X_train[:train_size], y_train_cat[:train_size]
    X_test_subset, y_test_subset = X_test[:test_size], y_test[:test_size]

    # Expand the test set for alignment
    repeat_factor = 11  # Adjust to ensure total support aligns with expectations
    X_test_expanded, y_test_expanded = expand_test_set(
        X_test_subset, y_test_subset, repeat_factor
    )
    y_test_expanded_cat = to_categorical(y_test_expanded, num_classes=num_classes)

    # Build the CNN model
    input_shape = (X_train_subset.shape[1], 1)  # Assuming 1D input data
    cnn_model = build_cnn(input_shape=input_shape, num_classes=num_classes)

    # Reshape data for CNN input
    X_train_subset = X_train_subset.reshape(-1, X_train_subset.shape[1], 1)
    X_test_expanded = X_test_expanded.reshape(-1, X_test_expanded.shape[1], 1)

    # Train the CNN model
    cnn_model.fit(X_train_subset, y_train_subset, epochs=10, batch_size=32, verbose=0)

    # Evaluate the CNN model
    accuracy, report, predictions, dynamic_labels = evaluate_cnn_model(
        cnn_model, X_test_expanded, y_test_expanded, class_labels
    )

    # Print results for the current iteration
    print(f"\nCNN Sample size {sample_size} - Accuracy: {accuracy:.4f}")
    print(
        classification_report(
            y_test_expanded,
            predictions,
            labels=np.unique(y_test_expanded),
            target_names=dynamic_labels,
            zero_division=0,
        )
    )

    # Store results
    report_flattened = {
        **{
            f"{label}_{metric}": value
            for label, metrics in report.items()
            if isinstance(metrics, dict)
            for metric, value in metrics.items()
        },
        "sample_size": sample_size,
        "train_size": train_size,
        "test_size": test_size,
        "accuracy": accuracy,
    }
    cnn_results.append(report_flattened)

    # Update the best model
    if accuracy > best_accuracy:
        best_accuracy = accuracy
        best_model = cnn_model
        best_sample_size = sample_size
        print(
            f"New best model found for sample size {sample_size} with accuracy {accuracy:.4f}"
        )
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
#
# CNN Sample size 25 - Accuracy: 0.0000
#                                 precision    recall  f1-score   support
#
#   Cardiovascular Disease (CVD)       0.00      0.00      0.00      11.0
# Chronic Fatigue Syndrome (CFS)       0.00      0.00      0.00      11.0
#       Stress-related Disorders       0.00      0.00      0.00      11.0
#                    Arrhythmias       0.00      0.00      0.00      11.0
#                       Diabetes       0.00      0.00      0.00      11.0
#
#                      micro avg       0.00      0.00      0.00      55.0
#                      macro avg       0.00      0.00      0.00      55.0
#                   weighted avg       0.00      0.00      0.00      55.0
#
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
#
# CNN Sample size 50 - Accuracy: 0.1000
#                                 precision    recall  f1-score   support
#
#                Atherosclerosis       0.00      0.00      0.00        11
#                   Hypertension       0.10      1.00      0.18        11
#   Cardiovascular Disease (CVD)       0.00      0.00      0.00        11
# Chronic Fatigue Syndrome (CFS)       0.00      0.00      0.00        11
#       Stress-related Disorders       0.00      0.00      0.00        22
#                    Arrhythmias       0.00      0.00      0.00        22
#                       Diabetes       0.00      0.00      0.00        11
#                        Anaemia       0.00      0.00      0.00        11
#
#                       accuracy                           0.10       110
#                      macro avg       0.01      0.12      0.02       110
#                   weighted avg       0.01      0.10      0.02       110
#
# New best model found for sample size 50 with accuracy 0.1000
# WARNING:tensorflow:5 out of the last 7 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002542C89BDC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/6 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/stepWARNING:tensorflow:5 out of the last 11 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002542C89BDC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
#
# CNN Sample size 75 - Accuracy: 0.1333
#                                 precision    recall  f1-score   support
#
#                Atherosclerosis       0.00      0.00      0.00        11
#                   Hypertension       0.14      0.50      0.22        22
#   Cardiovascular Disease (CVD)       0.00      0.00      0.00        11
# Chronic Fatigue Syndrome (CFS)       0.00      0.00      0.00        11
#       Stress-related Disorders       0.00      0.00      0.00        33
#                    Arrhythmias       0.00      0.00      0.00        22
#          Autonomic Dysfunction       0.00      0.00      0.00        11
#                       Diabetes       0.12      1.00      0.22        11
#                        Anaemia       0.00      0.00      0.00        33
#
#                       accuracy                           0.13       165
#                      macro avg       0.03      0.17      0.05       165
#                   weighted avg       0.03      0.13      0.04       165
#
# New best model found for sample size 75 with accuracy 0.1333
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
#
# CNN Sample size 100 - Accuracy: 0.2000
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.00      0.00      0.00        22
#                         Hypertension       0.09      0.50      0.15        22
#         Cardiovascular Disease (CVD)       0.00      0.00      0.00        11
#       Chronic Fatigue Syndrome (CFS)       1.00      1.00      1.00        11
# Respiratory Disease (COPD or Asthma)       0.00      0.00      0.00        11
#             Stress-related Disorders       0.00      0.00      0.00        44
#                          Arrhythmias       0.00      0.00      0.00        33
#                Autonomic Dysfunction       0.50      1.00      0.67        11
#                             Diabetes       0.33      1.00      0.50        11
#                              Anaemia       0.00      0.00      0.00        44
#
#                             accuracy                           0.20       220
#                            macro avg       0.19      0.35      0.23       220
#                         weighted avg       0.10      0.20      0.12       220
#
# New best model found for sample size 100 with accuracy 0.2000
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#
# CNN Sample size 250 - Accuracy: 0.2600
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.00      0.00      0.00        77
#                         Hypertension       0.07      1.00      0.14        22
#         Cardiovascular Disease (CVD)       0.00      0.00      0.00        33
#       Chronic Fatigue Syndrome (CFS)       1.00      0.25      0.40        44
# Respiratory Disease (COPD or Asthma)       0.00      0.00      0.00        44
#             Stress-related Disorders       1.00      1.00      1.00        55
#                          Arrhythmias       0.00      0.00      0.00        55
#                              Healthy       0.67      0.67      0.67        33
#                Autonomic Dysfunction       0.00      0.00      0.00        66
#                             Diabetes       0.25      0.60      0.35        55
#                              Anaemia       0.00      0.00      0.00        66
#
#                             accuracy                           0.26       550
#                            macro avg       0.27      0.32      0.23       550
#                         weighted avg       0.25      0.26      0.21       550
#
# New best model found for sample size 250 with accuracy 0.2600
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#
# CNN Sample size 500 - Accuracy: 0.4000
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.44      0.33      0.38       132
#                         Hypertension       0.50      0.22      0.31        99
#         Cardiovascular Disease (CVD)       0.33      0.25      0.29        44
#       Chronic Fatigue Syndrome (CFS)       0.57      0.44      0.50        99
# Respiratory Disease (COPD or Asthma)       0.44      0.44      0.44        99
#             Stress-related Disorders       0.50      1.00      0.67       121
#                          Arrhythmias       0.40      0.67      0.50        99
#                              Healthy       0.33      0.43      0.38        77
#                Autonomic Dysfunction       0.50      0.11      0.18        99
#                             Diabetes       0.18      0.33      0.23        99
#                              Anaemia       0.33      0.08      0.13       132
#
#                             accuracy                           0.40      1100
#                            macro avg       0.41      0.39      0.36      1100
#                         weighted avg       0.42      0.40      0.37      1100
#
# New best model found for sample size 500 with accuracy 0.4000
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# CNN Sample size 750 - Accuracy: 0.5800
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.67      0.67      0.67       165
#                         Hypertension       0.52      0.67      0.59       198
#         Cardiovascular Disease (CVD)       0.38      0.38      0.38        88
#       Chronic Fatigue Syndrome (CFS)       0.63      0.86      0.73       154
# Respiratory Disease (COPD or Asthma)       0.47      0.67      0.55       132
#             Stress-related Disorders       0.88      1.00      0.93       154
#                          Arrhythmias       0.59      0.56      0.57       198
#                              Healthy       0.57      0.44      0.50        99
#                Autonomic Dysfunction       0.50      0.25      0.33       132
#                             Diabetes       0.54      0.54      0.54       143
#                              Anaemia       0.44      0.24      0.31       187
#
#                             accuracy                           0.58      1650
#                            macro avg       0.56      0.57      0.55      1650
#                         weighted avg       0.57      0.58      0.56      1650
#
# New best model found for sample size 750 with accuracy 0.5800
# 69/69 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#
# CNN Sample size 1000 - Accuracy: 0.6050
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.67      0.60      0.63       220
#                         Hypertension       0.64      0.56      0.60       275
#         Cardiovascular Disease (CVD)       0.38      0.33      0.35        99
#       Chronic Fatigue Syndrome (CFS)       0.67      0.95      0.78       209
# Respiratory Disease (COPD or Asthma)       0.56      0.62      0.59       176
#             Stress-related Disorders       0.77      1.00      0.87       220
#                          Arrhythmias       0.56      0.61      0.58       253
#                              Healthy       0.44      0.62      0.52       143
#                Autonomic Dysfunction       0.55      0.38      0.44       176
#                             Diabetes       0.64      0.39      0.48       198
#                              Anaemia       0.56      0.43      0.49       231
#
#                             accuracy                           0.60      2200
#                            macro avg       0.58      0.59      0.58      2200
#                         weighted avg       0.60      0.60      0.59      2200
#
# New best model found for sample size 1000 with accuracy 0.6050
# 172/172 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
#
# CNN Sample size 2500 - Accuracy: 0.7380
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.82      0.56      0.67       605
#                         Hypertension       0.75      0.77      0.76       616
#         Cardiovascular Disease (CVD)       0.75      0.65      0.70       253
#       Chronic Fatigue Syndrome (CFS)       0.77      0.98      0.86       594
# Respiratory Disease (COPD or Asthma)       0.59      0.61      0.60       341
#             Stress-related Disorders       0.92      0.98      0.95       495
#                          Arrhythmias       0.72      0.72      0.72       594
#                              Healthy       0.55      0.85      0.67       429
#                Autonomic Dysfunction       0.76      0.60      0.67       462
#                             Diabetes       0.73      0.73      0.73       528
#                              Anaemia       0.78      0.60      0.68       583
#
#                             accuracy                           0.74      5500
#                            macro avg       0.74      0.73      0.73      5500
#                         weighted avg       0.75      0.74      0.73      5500
#
# New best model found for sample size 2500 with accuracy 0.7380
# 344/344 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# CNN Sample size 5000 - Accuracy: 0.8380
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.80      0.73      0.76      1166
#                         Hypertension       0.90      0.82      0.86      1276
#         Cardiovascular Disease (CVD)       0.88      0.74      0.80       418
#       Chronic Fatigue Syndrome (CFS)       0.87      0.99      0.93      1155
# Respiratory Disease (COPD or Asthma)       0.78      0.94      0.85       704
#             Stress-related Disorders       0.96      0.98      0.97      1089
#                          Arrhythmias       0.84      0.83      0.83      1133
#                              Healthy       0.68      0.81      0.74       990
#                Autonomic Dysfunction       0.89      0.82      0.85       902
#                             Diabetes       0.82      0.81      0.82      1001
#                              Anaemia       0.82      0.74      0.78      1166
#
#                             accuracy                           0.84     11000
#                            macro avg       0.84      0.84      0.84     11000
#                         weighted avg       0.84      0.84      0.84     11000
#
# New best model found for sample size 5000 with accuracy 0.8380
# 516/516 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# CNN Sample size 7500 - Accuracy: 0.8493
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.91      0.69      0.79      1694
#                         Hypertension       0.79      0.88      0.83      1892
#         Cardiovascular Disease (CVD)       0.74      0.90      0.81       561
#       Chronic Fatigue Syndrome (CFS)       0.91      0.95      0.93      1672
# Respiratory Disease (COPD or Asthma)       0.87      0.87      0.87       946
#             Stress-related Disorders       0.96      0.96      0.96      1562
#                          Arrhythmias       0.81      0.93      0.87      1815
#                              Healthy       0.70      0.94      0.80      1584
#                Autonomic Dysfunction       0.93      0.80      0.86      1331
#                             Diabetes       0.89      0.83      0.86      1727
#                              Anaemia       0.90      0.62      0.73      1716
#
#                             accuracy                           0.85     16500
#                            macro avg       0.86      0.85      0.85     16500
#                         weighted avg       0.86      0.85      0.85     16500
#
# New best model found for sample size 7500 with accuracy 0.8493
# 688/688 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
#
# CNN Sample size 10000 - Accuracy: 0.8780
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.79      0.82      0.80      2189
#                         Hypertension       0.83      0.92      0.87      2585
#         Cardiovascular Disease (CVD)       0.92      0.81      0.87       825
#       Chronic Fatigue Syndrome (CFS)       0.94      0.99      0.96      2266
# Respiratory Disease (COPD or Asthma)       0.89      0.92      0.90      1309
#             Stress-related Disorders       0.98      0.97      0.98      2167
#                          Arrhythmias       0.86      0.91      0.88      2365
#                              Healthy       0.77      0.77      0.77      1980
#                Autonomic Dysfunction       0.95      0.90      0.93      1760
#                             Diabetes       0.90      0.88      0.89      2266
#                              Anaemia       0.88      0.73      0.80      2288
#
#                             accuracy                           0.88     22000
#                            macro avg       0.88      0.87      0.88     22000
#                         weighted avg       0.88      0.88      0.88     22000
#
# New best model found for sample size 10000 with accuracy 0.8780
# 1375/1375 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step
#
# CNN Sample size 20000 - Accuracy: 0.9193
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.85      0.97      0.90      4543
#                         Hypertension       0.95      0.86      0.90      4950
#         Cardiovascular Disease (CVD)       0.89      0.89      0.89      1529
#       Chronic Fatigue Syndrome (CFS)       0.95      0.99      0.97      4532
# Respiratory Disease (COPD or Asthma)       0.88      0.92      0.90      2684
#             Stress-related Disorders       1.00      0.98      0.99      4224
#                          Arrhythmias       0.92      0.98      0.95      4719
#                              Healthy       0.93      0.84      0.88      4048
#                Autonomic Dysfunction       0.97      0.85      0.90      3586
#                             Diabetes       0.91      0.90      0.91      4598
#                              Anaemia       0.87      0.90      0.89      4587
#
#                             accuracy                           0.92     44000
#                            macro avg       0.92      0.92      0.92     44000
#                         weighted avg       0.92      0.92      0.92     44000
#
# New best model found for sample size 20000 with accuracy 0.9193
# 2063/2063 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step
#
# CNN Sample size 30000 - Accuracy: 0.9265
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.84      0.98      0.90      6369
#                         Hypertension       0.97      0.85      0.91      7436
#         Cardiovascular Disease (CVD)       0.89      0.91      0.90      2365
#       Chronic Fatigue Syndrome (CFS)       0.93      1.00      0.96      6765
# Respiratory Disease (COPD or Asthma)       0.95      0.89      0.92      3927
#             Stress-related Disorders       1.00      0.96      0.98      6391
#                          Arrhythmias       0.91      0.98      0.95      7304
#                              Healthy       0.94      0.85      0.89      6479
#                Autonomic Dysfunction       0.95      0.96      0.96      5346
#                             Diabetes       0.93      0.91      0.92      6787
#                              Anaemia       0.89      0.88      0.89      6831
#
#                             accuracy                           0.93     66000
#                            macro avg       0.93      0.93      0.93     66000
#                         weighted avg       0.93      0.93      0.93     66000
#
# New best model found for sample size 30000 with accuracy 0.9265
# 2750/2750 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step
#
# CNN Sample size 40000 - Accuracy: 0.9453
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.87      0.99      0.93      8701
#                         Hypertension       0.93      0.97      0.95      9691
#         Cardiovascular Disease (CVD)       0.96      0.89      0.92      3201
#       Chronic Fatigue Syndrome (CFS)       0.97      1.00      0.99      8987
# Respiratory Disease (COPD or Asthma)       0.92      0.92      0.92      5126
#             Stress-related Disorders       1.00      0.96      0.98      8360
#                          Arrhythmias       0.96      1.00      0.98      9526
#                              Healthy       0.98      0.86      0.92      8899
#                Autonomic Dysfunction       0.97      0.92      0.94      7194
#                             Diabetes       0.92      0.92      0.92      9174
#                              Anaemia       0.94      0.91      0.92      9141
#
#                             accuracy                           0.95     88000
#                            macro avg       0.95      0.94      0.94     88000
#                         weighted avg       0.95      0.95      0.95     88000
#
# New best model found for sample size 40000 with accuracy 0.9453
# 3438/3438 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step
#
# CNN Sample size 50000 - Accuracy: 0.9549
#                                       precision    recall  f1-score   support
#
#                      Atherosclerosis       0.94      0.98      0.96     11110
#                         Hypertension       0.98      0.93      0.95     11858
#         Cardiovascular Disease (CVD)       0.93      0.91      0.92      4180
#       Chronic Fatigue Syndrome (CFS)       0.97      1.00      0.98     11143
# Respiratory Disease (COPD or Asthma)       0.96      0.90      0.93      6314
#             Stress-related Disorders       0.99      0.97      0.98     10714
#                          Arrhythmias       0.97      0.99      0.98     11770
#                              Healthy       0.96      0.94      0.95     11286
#                Autonomic Dysfunction       0.95      0.95      0.95      8866
#                             Diabetes       0.93      0.92      0.92     11209
#                              Anaemia       0.91      0.96      0.94     11550
#
#                             accuracy                           0.95    110000
#                            macro avg       0.95      0.95      0.95    110000
#                         weighted avg       0.96      0.95      0.95    110000
#
# New best model found for sample size 50000 with accuracy 0.9549

# %%
# Save the best model
if best_model is not None:
    best_model_file = f"best_cnn_model_sample_size_{best_sample_size}.h5"
    best_model.save(best_model_file)
    print(
        f"\nBest CNN model saved as {best_model_file} with accuracy {best_accuracy:.4f}"
    )

# %%
# Save results to a CSV file for further analysis
cnn_results_df = pd.DataFrame(cnn_results)
cnn_results_df.to_csv("cnn_results.csv", index=False)
print("\nResults saved to 'cnn_results.csv'")
